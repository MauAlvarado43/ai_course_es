# %% [markdown]
# Árboles de decisión (regresión)
# ==========================
# Son un conjunto de árboles de decisión donde cada uno es entrenado con una muestra de datos distinta del entrenamiento y al predecir datos, se calcula la media de todas las predicciones dadas por cada árbol.
#
# <center>
#
# ![image.png](attachment:image.png)
#
# </center>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Importamos el dataset
dataset = pd.read_csv('./datasets/Position_Salaries.csv')
X = dataset.iloc[:, 1:2].values
y = dataset.iloc[:, 2].values

# %%
# Entrenamos el modelo
from sklearn.ensemble import RandomForestRegressor
regression = RandomForestRegressor(n_estimators = 300, random_state = 0)
regression.fit(X, y)

# %%
# Visualizamos los resultados
X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape(len(X_grid), 1)
plt.scatter(X, y, color = "red")
plt.plot(X_grid, regression.predict(X_grid), color = "blue")
plt.title("Random Forest Regression")
plt.xlabel("Level")
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# Referencias:
#
# * https://levelup.gitconnected.com/random-forest-regression-209c0f354c84
#
# * https://www.cienciadedatos.net/documentos/py08_random_forest_python.html
